# %% [raw]
# ---
# description: Repo to use artificial vision to compare a product with its CAD model
# output-file: index.html
# title: vision-cad
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install vision_cad in Development mode

# %% [markdown]
# ```sh
# # make sure vision_cad package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to vision_cad
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ramonpr/vision-cad.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ramonpr vision_cad
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install vision_cad
# ```
#
#
# [repo]: https://github.com/ramonpr/vision-cad
# [docs]: https://ramonpr.github.io/vision-cad/
# [pypi]: https://pypi.org/project/vision-cad/
# [conda]: https://anaconda.org/ramonpr/vision-cad

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ramonpr/vision-cad
# [docs]: https://ramonpr.github.io/vision-cad/
# [pypi]: https://pypi.org/project/vision-cad/
# [conda]: https://anaconda.org/ramonpr/vision-cad

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
